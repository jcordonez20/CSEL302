# %% [markdown]
# # **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# # **1.Data Exploration**

# %%
data_path = 'Lesson_4_student_grades_dataset.csv'
dataset = pd.read_csv(data_path)
X = dataset.drop('Grades', axis = 1)
Y = dataset[['Grades']]
dataset.head()
# Out:
#    Hours_of_Study  Attendance_Percentage  Previous_Exam_Scores  \
# 0        4.370861              75.553988             63.085284
# 1        9.556429              86.257028             62.348940
# 2        7.587945              96.188375             95.312729
# 3        6.387926              91.966747             62.477310
# 4        2.404168              94.196834             63.597486
#
#    Extracurricular_Activities  Travel_Time_to_School     Grades
# 0                           0              24.325977  31.494329
# 1                           0              50.132016  43.250150
# 2                           0              59.861895  30.155663
# 3                           1              11.501300  39.617522
# 4                           0              54.868293  33.175874

# %% [markdown]
# # **2. Data Preprocessing**

# %%
print(dataset.isnull().sum())
# Out:
# Hours_of_Study                0
# Attendance_Percentage         0
# Previous_Exam_Scores          0
# Extracurricular_Activities    0
# Travel_Time_to_School         0
# Grades                        0
# dtype: int64

# %% [markdown]
# # **3. Train-Test Split**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=42)

# %% [markdown]
# # **4. Linear Regression Model**

# %%
# Hours of Study

X = dataset[['Hours_of_Study']]
Y = dataset[['Grades']]


model = LinearRegression()
model.fit(X,Y)

slope = model.coef_[0]
intercept = model.intercept_

print('Slope', slope)
print('Intercept', intercept)

plt.scatter(X,Y)
plt.plot(X, model.predict(X), color='red')
plt.xlabel('Hours of Study')
plt.ylabel('Grades')
plt.show()
# Out:
# Slope [0.31185559]
# Intercept [34.50375609]

# %%
# Attendance Percentage

X = dataset[['Attendance_Percentage']]
Y = dataset[['Grades']]


model = LinearRegression()
model.fit(X,Y)

slope = model.coef_[0]
intercept = model.intercept_

print('Slope', slope)
print('Intercept', intercept)

plt.scatter(X,Y)
plt.plot(X, model.predict(X), color='red')
plt.xlabel('Attendance Percentage')
plt.ylabel('Grades')
plt.show()
# Out:
# Slope [0.23095043]
# Intercept [16.51220848]

# %%
# Previous Exam Scores

X = dataset[['Previous_Exam_Scores']]
Y = dataset[['Grades']]


model = LinearRegression()
model.fit(X,Y)

slope = model.coef_[0]
intercept = model.intercept_

print('Slope', slope)
print('Intercept', intercept)

plt.scatter(X,Y)
plt.plot(X, model.predict(X), color='red')
plt.xlabel('Previous Exam Scores')
plt.ylabel('Grades')
plt.show()
# Out:
# Slope [0.2556363]
# Intercept [16.98814303]

# %%
# Extracurricular Activities

X = dataset[['Extracurricular_Activities']]
Y = dataset[['Grades']]


model = LinearRegression()
model.fit(X,Y)

slope = model.coef_[0]
intercept = model.intercept_

print('Slope', slope)
print('Intercept', intercept)

plt.scatter(X,Y)
plt.plot(X, model.predict(X), color='red')
plt.xlabel('Extracurricular Activities')
plt.ylabel('Grades')
plt.show()
# Out:
# Slope [5.28155266]
# Intercept [33.59837253]

# %%
# Travel Time to School

X = dataset[['Travel_Time_to_School']]
Y = dataset[['Grades']]


model = LinearRegression()
model.fit(X,Y)

slope = model.coef_[0]
intercept = model.intercept_

print('Slope', slope)
print('Intercept', intercept)

plt.scatter(X,Y)
plt.plot(X, model.predict(X), color='red')
plt.xlabel('Travel Time to School')
plt.ylabel('Grades')
plt.show()
# Out:
# Slope [-0.09305324]
# Intercept [39.37929043]

# %% [markdown]
# # **5. Model Training**

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # **6. Predictions & Evaluation**

# %%
# Blanko

# %% [markdown]
# # **7. Feature Importance Analysis**

# %%
prediction = model.predict(X_test)
plt.scatter(Y_test, prediction)
plt.plot(Y_test, Y_test, color='red')
plt.xlabel('Predict')
plt.ylabel('Actual')
plt.show()

print('Coefficient', model.coef_)
print('Intercept', model.intercept_)
# Out:
# Coefficient [[ 0.33491143  0.20253934  0.25216937  4.87399857 -0.09033945]]
# Intercept [-1.1380583]

# %% [markdown]
# # **8. Discussion**

# %%
print("""
It appears to me that the Extracurricular Activities
has the biggest effect on grades since it 
Having a higher coefficient of 4.87 and a slope of 5, compared to the others.
""")

print("""
For me, the most unexpected notice is that the school's travel time
has little impact on the academic standing of the students because of its negative slope.
""")
# Out:
# For me it looks like the Extracurricular Activities
# has the most significant impact on the grades since that it
# has a slope of 5 and a coefficient of 4.87 which is higher than the others.
#
#
# The most surprising finding for me is that the Travel Time Of School
# has the least impact to the student's grades since it has a negative slope
# and coefficient making it the least impactful.

# %% [markdown]
# # **9. Scenario Extension**

# %%
print("""
If a person had a disability or mental illness, I would think that
both of them are certain to have an impact on their grades.
Depending on the handicap, the grades are affected in a mental or physical way.
""")
# Out:
# I would think that if someone is born with a disability or mental disorder
# it would probably affect the grades since that both of them would most likely
# affect the grades either physically or mentally depending on the disability.

# %% [markdown]
# # **10. Reflection**

# %%
print("""
The problem that I encountered was not knowing what I would do in such a situation. I asked my classmates what they did on the numbers that I was unsure of how to handle because there were several numbers in the pdf.
""")

print("""
Certain models have a major impact on grades, while others have little effect on
the grades.
""")

print("""
If an employee's wage is higher, this model may be used to assess how hard and effectively they work.
""")
# Out:
# The challenge that i faced was that i didn't understand what i would do in
# each number in the pdf so what i did was ask my classmates on what they did
# on the number that i didn't know what to do.
#
#
# The difference in features of each model is on how they affect grades
# some models affects the grades very significantly and some doesn't affect
# the grades at all.
#
#
# This model could be used to determine on how employees work hard and efficient
# if their salary is higher.
